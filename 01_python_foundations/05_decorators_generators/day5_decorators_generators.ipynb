# %% [markdown]
# # Day 5 — Decorators & Generators
#
# > Follow along with [`guides/week01_python_sprint.md`](../../guides/week01_python_sprint.md).
# > Rules: type everything yourself · no copy-paste · finish with a commit.
#
# **Study first:** [Real Python decorators primer](https://realpython.com/primer-on-python-decorators/) — closures first, then decorators + `functools.wraps`; generators (`yield`, generator expressions); skim `itertools` (`count`, `islice`, `chain`).

# %% [markdown]
# ## Exercise 1 — Closure
#
# `make_multiplier(n)` returns a function that multiplies by n.

# %%
def make_multiplier(n):
    pass  # TODO

# double = make_multiplier(2); double(5) == 10

# %% [markdown]
# ## Exercise 2 — @timer
#
# Prints how long the function took. Use `functools.wraps`.

# %%
import time
from functools import wraps

def timer(func):
    pass  # TODO

# %% [markdown]
# ## Exercise 3 — @logger + stacking
#
# Prints function name + arguments on each call. Stack it with `@timer` — which runs first? Answer in a comment.

# %%
# TODO
# Stacking order answer:

# %% [markdown]
# ## Exercise 4 — @retry(times=3)
#
# A decorator **with an argument** that retries on exception.

# %%
def retry(times=3):
    pass  # TODO: decorator factory

# %% [markdown]
# ## Exercise 5 — Infinite fibonacci
#
# Generator `fibonacci()` — infinite; take the first 20 with `itertools.islice`.

# %%
from itertools import islice

def fibonacci():
    pass  # TODO: yield forever

# %% [markdown]
# ## Exercise 6 — Lazy file reader
#
# `read_large_file(path)` yields one line at a time. Comment: why does this beat `f.readlines()` for a 10 GB file?

# %%
def read_large_file(path):
    pass  # TODO
# Why better than readlines()?:

# %% [markdown]
# ## Exercise 7 — Generator expression
#
# Sum of squares under 1,000,000 without building a list in memory.

# %%
# TODO: sum(... for ...)

# %% [markdown]
# ## 🎤 Interview questions of the day
#
# Answer **out loud first**, then write your answer below, then copy it into [`04_interview_prep/python_qa.md`](../../04_interview_prep/python_qa.md).
#
# **Q9: What is a decorator? What problem does `functools.wraps` solve?**
#
# **Q10: Generator vs list — the memory tradeoff. What does `yield` do to a function's execution?**

# %% [markdown]
# *Your answers:*
#
# -
# -

# %% [markdown]
# ---
# ✅ **Done? Tick Day off in [`PROGRESS.md`](../../PROGRESS.md), then commit:**
#
# ```
# git add -A && git commit -m "Day 5: decorators (timer/logger/retry) + generators" && git push
# ```
