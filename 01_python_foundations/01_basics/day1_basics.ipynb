# %% [markdown]
# # Day 1 — Setup, Variables, Strings, Control Flow
#
# > Follow along with [`guides/week01_python_sprint.md`](../../guides/week01_python_sprint.md).
# > Rules: type everything yourself · no copy-paste · finish with a commit.
#
# **Study first (60–90 min):** [Python tutorial ch. 3–4](https://docs.python.org/3/tutorial/introduction.html) — variables, `int/float/str/bool`, f-strings, `if/elif/else`, `for`, `while`, `range`, `break/continue`.

# %% [markdown]
# ## Exercise 1 — FizzBuzz (1–50)
#
# Print numbers 1–50. Multiples of 3 → 'Fizz', of 5 → 'Buzz', of both → 'FizzBuzz'.

# %%
for i in range(1, 51):
    pass  # TODO

# %% [markdown]
# ## Exercise 2 — String operations
#
# Given a string, print it reversed, uppercased, and report its vowel count — using f-strings only.

# %%
text = "the shadow monarch arises"
# TODO: reversed, uppercased, vowel count — all printed with f-strings

# %% [markdown]
# ## Exercise 3 — Guess-the-number game
#
# Random target 1–100, loop until guessed, count attempts. ⚠️ Lesson from your old `hell0.py`: `input()` returns a **str** — `guess == 50` is never true until you convert with `int()`.

# %%
import random

target = random.randint(1, 100)
# TODO: while loop, int(input(...)), higher/lower hints, attempt counter

# %% [markdown]
# ## Exercise 4 — Star triangle
#
# Print a right triangle of `*` of height n using nested loops.

# %%
n = 5
# TODO

# %% [markdown]
# ## Exercise 5 — Divisible sum, two ways
#
# Sum all numbers 1–1000 divisible by 3 or 5: once with a plain loop, once with `sum()` + `range` in one line.

# %%
# TODO: version 1 — loop

# TODO: version 2 — sum() one-liner

# %% [markdown]
# ## 🎤 Interview questions of the day
#
# Answer **out loud first**, then write your answer below, then copy it into [`04_interview_prep/python_qa.md`](../../04_interview_prep/python_qa.md).
#
# **Q1: What's the difference between `is` and `==` in Python?**
#
# **Q2: Is Python pass-by-value or pass-by-reference? What actually happens when you pass a list to a function?**

# %% [markdown]
# *Your answers:*
#
# -
# -

# %% [markdown]
# ---
# ✅ **Done? Tick Day off in [`PROGRESS.md`](../../PROGRESS.md), then commit:**
#
# ```
# git add -A && git commit -m "Day 1: basics + control flow — FizzBuzz, string ops, guessing game" && git push
# ```
