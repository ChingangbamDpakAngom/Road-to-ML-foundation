# %% [markdown]
# ### variable

# %%
# example
x = 5
print(x)

# %%
def get_guess():
    guess = input("enter a number:")
    return guess

def main():
    guess = get_guess()
    print('You entered:', guess)
