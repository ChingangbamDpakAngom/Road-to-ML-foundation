# %% [markdown]
# # Day 3 — Functions & Functional Python
#
# > Follow along with [`guides/week01_python_sprint.md`](../../guides/week01_python_sprint.md).
# > Rules: type everything yourself · no copy-paste · finish with a commit.
#
# **Study first:** functions, default args (⚠️ the mutable-default trap), `*args/**kwargs`, returning tuples, scope/LEGB, `lambda`, `map`, `filter`, `functools.reduce`, `sorted(key=...)`.

# %% [markdown]
# ## Exercise 1 — stats(*numbers)
#
# Returns `(mean, min, max)` as a tuple; call it with a list using `*` unpacking.

# %%
def stats(*numbers):
    pass  # TODO

nums = [3, 9, 1, 7, 5]
# TODO: call with * unpacking

# %% [markdown]
# ## Exercise 2 — Mutable default argument bug
#
# Demonstrate the bug with `def f(x, acc=[])`, then fix it with `None`.

# %%
def buggy(x, acc=[]):
    acc.append(x)
    return acc

# TODO: call twice, observe the bug, then write the fixed version

# %% [markdown]
# ## Exercise 3 — Multi-key sorting
#
# Sort `(name, age, salary)` tuples by salary desc, then age asc — `sorted` with a `lambda` key.

# %%
people = [("ana", 30, 50000), ("bo", 25, 62000), ("cy", 35, 62000)]
# TODO

# %% [markdown]
# ## Exercise 4 — Comprehension vs map/filter
#
# Squares of evens 1–20, and lengths of words longer than 4 — each written BOTH ways. Comment which reads better.

# %%
# TODO: comprehension versions

# TODO: map/filter versions

# %% [markdown]
# ## Exercise 5 — reduce
#
# Product of a list, then the longest word — both with `functools.reduce`.

# %%
from functools import reduce
nums = [1, 2, 3, 4, 5]
words = ["arise", "shadow", "monarch"]
# TODO

# %% [markdown]
# ## Exercise 6 — apply_n_times
#
# `apply_n_times(func, x, n)` applies func to x, n times. Test with `lambda v: v*2`.

# %%
def apply_n_times(func, x, n):
    pass  # TODO

# expect: apply_n_times(lambda v: v*2, 1, 10) == 1024

# %% [markdown]
# ## 🎤 Interview questions of the day
#
# Answer **out loud first**, then write your answer below, then copy it into [`04_interview_prep/python_qa.md`](../../04_interview_prep/python_qa.md).
#
# **Q5: What is the LEGB rule? What do `global` and `nonlocal` do?**
#
# **Q6: What are `*args` and `**kwargs`? Show a real use case (e.g., a wrapper function).**

# %% [markdown]
# *Your answers:*
#
# -
# -

# %% [markdown]
# ---
# ✅ **Done? Tick Day off in [`PROGRESS.md`](../../PROGRESS.md), then commit:**
#
# ```
# git add -A && git commit -m "Day 3: functions, lambda, map/filter/reduce" && git push
# ```
