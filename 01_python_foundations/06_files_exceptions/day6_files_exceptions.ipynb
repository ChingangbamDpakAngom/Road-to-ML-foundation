# %% [markdown]
# # Day 6 — Files, Exceptions, Context Managers, Type Hints
#
# > Follow along with [`guides/week01_python_sprint.md`](../../guides/week01_python_sprint.md).
# > Rules: type everything yourself · no copy-paste · finish with a commit.
#
# **Study first:** `open` modes, `with` blocks, `pathlib.Path`, `json`, `csv`; `try/except/else/finally`, raising, custom exceptions; type hints (`list[int]`, `dict[str, float]`, `Optional`).

# %% [markdown]
# ## Exercise 1 — JSON round-trip
#
# Write a dict to JSON, read it back, verify equality.

# %%
import json
from pathlib import Path
# TODO

# %% [markdown]
# ## Exercise 2 — CSV averages
#
# Read a CSV of students+scores, compute averages, write results to a new CSV. (Create the input CSV in code first.)

# %%
import csv
# TODO

# %% [markdown]
# ## Exercise 3 — safe_divide
#
# Full `try/except/else/finally`; returns `None` on division by zero with a warning.

# %%
def safe_divide(a, b):
    pass  # TODO

# %% [markdown]
# ## Exercise 4 — Custom exception
#
# Define `InsufficientFundsError` and retrofit it into Day 4's bank `withdraw`.

# %%
class InsufficientFundsError(Exception):
    pass
# TODO

# %% [markdown]
# ## Exercise 5 — Your own context manager
#
# A class with `__enter__`/`__exit__` that times a code block; then redo with `@contextlib.contextmanager`.

# %%
import time
from contextlib import contextmanager
# TODO: both versions

# %% [markdown]
# ## Exercise 6 — Type hints + mypy
#
# Copy your Day 4 bank code into a `bank.py` next to this notebook, add type hints to ALL of it, run `mypy bank.py` in a terminal, fix every error.

# %%
# Paste your final, mypy-clean bank code here for the record

# %% [markdown]
# ## 🎤 Interview questions of the day
#
# Answer **out loud first**, then write your answer below, then copy it into [`04_interview_prep/python_qa.md`](../../04_interview_prep/python_qa.md).
#
# **Q11: What does `with` do? What are `__enter__` and `__exit__`?**
#
# **Q12: `except Exception` vs bare `except:` — why is the bare one dangerous?**

# %% [markdown]
# *Your answers:*
#
# -
# -

# %% [markdown]
# ---
# ✅ **Done? Tick Day off in [`PROGRESS.md`](../../PROGRESS.md), then commit:**
#
# ```
# git add -A && git commit -m "Day 6: file I/O, exceptions, context managers, mypy-clean bank" && git push
# ```
