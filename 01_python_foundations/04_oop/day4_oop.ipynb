# %% [markdown]
# # Day 4 — OOP: Bank Account System ⚠️ FALLBACK CHECKPOINT
#
# > Follow along with [`guides/week01_python_sprint.md`](../../guides/week01_python_sprint.md).
# > Rules: type everything yourself · no copy-paste · finish with a commit.
#
# **Study first:** [Real Python OOP](https://realpython.com/python3-object-oriented-programming/) — classes, `__init__`, instance vs class attributes, inheritance, `super()`, dunders (`__str__`, `__repr__`, `__len__`, `__eq__`), `@property`.
#
# **Checkpoint:** if Days 1–4 aren't done by tonight and you're >1 day behind, switch to the 2-week pace (see guide).

# %% [markdown]
# ## Exercise 1 — Account class
#
# `owner`, `balance`; `deposit`, `withdraw` (no overdraft — raise `ValueError`), a nice `__str__`.

# %%
class Account:
    def __init__(self, owner, balance=0):
        pass  # TODO

# %% [markdown]
# ## Exercise 2 — SavingsAccount(Account)
#
# Adds `interest_rate` and `apply_interest()`; must use `super().__init__`.

# %%
# TODO

# %% [markdown]
# ## Exercise 3 — Dunders + history
#
# Keep a transaction history list. `__eq__` (same owner+balance), `__len__` (transaction count).

# %%
# TODO: extend Account

# %% [markdown]
# ## Exercise 4 — @property
#
# Make `balance` a read-only property so it can't be set directly from outside.

# %%
# TODO

# %% [markdown]
# ## Exercise 5 — Bank class
#
# Holds many accounts: open account, find by owner, total assets.

# %%
# TODO

# %% [markdown]
# ## 🎤 Interview questions of the day
#
# Answer **out loud first**, then write your answer below, then copy it into [`04_interview_prep/python_qa.md`](../../04_interview_prep/python_qa.md).
#
# **Q7: `__str__` vs `__repr__`? Class attribute vs instance attribute — show a bug caused by confusing them.**
#
# **Q8: What is MRO (method resolution order)? What does `super()` actually do in multiple inheritance?**

# %% [markdown]
# *Your answers:*
#
# -
# -

# %% [markdown]
# ---
# ✅ **Done? Tick Day off in [`PROGRESS.md`](../../PROGRESS.md), then commit:**
#
# ```
# git add -A && git commit -m "Day 4: OOP — bank account system with inheritance and dunders" && git push
# ```
